# %%
#@title TTS Trainer with Language
# !sudo apt update
# !sudo apt-get install python3.9-venv -y

from google.colab import drive
drive.mount('/content/drive')

# %cd /content/
# !pip install git+https://git.ecker.tech/mrq/vall-e
# !pip install git+https://github.com/suno-ai/bark.git

# %cd /content/
# !git clone https://git.ecker.tech/mrq/ai-voice-cloning/
# !cp -r /content/drive/MyDrive/Project/Deepfake/Models/TTS/training /content/ai-voice-cloning/
# !cp -r /content/drive/MyDrive/Project/Deepfake/Models/TTS/voices /content/ai-voice-cloning/
# !ln -s ./ai-voice-cloning/models/ ./
# %cd ai-voice-cloning
# !./setup-cuda.sh

# %cd /content/ai-voice-cloning/
# !sudo apt update
# !sudo apt-get install python3.9-venv -y
# !mkdir -p ~/.cache
# !ln -s /content/ai-voice-cloning/models/voicefixer ~/.cache/.

# !pip install virtualenv
# !mkdir /content/ai-voice-cloning/voices/modiji
# !cp /content/drive/MyDrive/Project/Deepfake/Datasets/Tortoise/*.wav /content/ai-voice-cloning/voices/modiji
# %cd /content/ai-voice-cloning/

# !export TORTOISE_MODELS_DIR=/content/ai-voice-cloning/models/tortoise/
# !export TRANSFORMERS_CACHE=/content/ai-voice-cloning/models/transformers/

# !pip uninstall beartype
# !pip install beartype==0.15.0

# !./start.sh --share

# %%
# !./start.sh --share

# %%
# !cp -r /content/ai-voice-cloning/training/modiji /content/drive/MyDrive/Project/Deepfake/Models/TTS/training
# !cp -r /content/ai-voice-cloning/voices/modiji /content/drive/MyDrive/Project/Deepfake/Models/TTS/voices
